# %%
import pymongo
from bs4 import BeautifulSoup
import time
import numpy as np
import pandas as pd
from  datetime import datetime, timedelta

# %%
def timeit(method):
    def timed(*args, **kw):
        ts = time.time()
        result = method(*args, **kw)
        te = time.time()
        if 'log_time' in kw:
            name = kw.get('log_name', method.__name__.upper())
            kw['log_time'][name] = int((te - ts) * 1000)
        else:
            print ('%r  %2.2f ms' % \
                  (method.__name__, (te - ts) * 1000))
        return result
    return timed

@timeit
def parse_auction_page(html):
    auction_title=html.split(qauction_id + " - ")[1]
    card_value, auction_title = auction_title.split(" ", 1)
    has_bids = "Bids" in auction_title
    has_gift_card = "Gift Card" in auction_title
    cash_value = auction_title.split("(")[1]
    cash_value = cash_value.split(")")[0][1:]
    if has_bids and has_gift_card:
        card_type, bid_value = auction_title.split (" Gift Card AND", 1)
        bid_value = bid_value.split(" Bids")[0][1:]
    elif has_gift_card and not has_bids:
        card_type = auction_title.split (" Gift Card")[0]
        bid_value = "0"  
    elif has_bids and not has_gift_card:
        card_type = "None"
        bid_value = card_value
        card_value = "$0"
    else:
        print("what is this?")               
    limited_allowed = "is NOT LIMITED" not in html
    auction_dict["cashvalue"] = int(cash_value)
    auction_dict["cardvalue"]=int(card_value[1:])
    auction_dict["bidvalue"]=int(bid_value)
    auction_dict["cardtype"]=card_type
    auction_dict["limited_allowed"]=limited_allowed

    
    
@timeit
def parse_auction_table_page(html):
    soup = BeautifulSoup(html, 'html.parser')
    tds = soup.find_all("td")
    tracking = str(tds[0]).split('%')[0].split()[1]
    last_update = str(tds[1]).split ("update: ")[1].split("</td>")[0]    
    run_time = str(tds[3]).split("runtime : ")[1].split("</td>")[0]
    auction_dict["tracking"] = float(tracking)
    auction_dict["auctiontime"] = datetime.strptime(last_update, '%m/%d/%Y %I:%M:%S %p') #last_update
    t = datetime.strptime(run_time, "%H:%M:%S")
    delta = timedelta(hours=t.hour, minutes=t.minute, seconds=t.second)
    auction_dict["runtime"] = t.hour*3600+t.minute*60+t.second
    lock_price = html.split('<div id="div_lock_prcnt" style="display: none;">')[1].split("<")[0]  
    if (lock_price):
        lock_price = int(float(lock_price)*100)
    auction_dict["lock_price"] = lock_price
    
@timeit
def parse_history_page(html, bids_list):
    soup = BeautifulSoup(html, 'html.parser')
    tds = soup.find_all("td")[3:]
    for i in range(0, len(tds), 4):
        bid = tds[i].text.strip() 
        user = tds[i+2].text.strip() 
        bid_type = tds[i+3].text.strip()   
        is_bidomatic = bid_type=="Bidomatic"
        bids_list.append({"auction_id": int(qauction_id), "bid": int(bid), "user": user, "is_bidomatic": is_bidomatic})

# %%
myclient = pymongo.MongoClient("mongodb://localhost:27017/")
db = myclient["penny"]
pages_collection = db["pages"]
auction_collection = db["auctions"]
bids_collection = db["bids"]

auction_list = []
    

#conn = pg2.connect(user='postgres',  dbname='penny', host='localhost', port='5432', password='')

#with conn.cursor() as cursor:
#    sql = "SELECT qauctionid from Auctions"
#    cursor.execute(sql)
#    already_got_qids = [qid[0] for qid in cursor.fetchall()]

#    print(already_got_qids)    

#    i = 0
for p in pages_collection.find({}):
    qauction_id = p['_id']
    if auction_collection.count_documents({"_id":int(qauction_id)})==0:
#    if int(qauction_id) not in already_got_qids:
        print(qauction_id, p['AuctionGroup'])
        auction_dict = {"_id": int(qauction_id)}
        bids_list = []
        parse_auction_page(p['Auction'])
        parse_auction_table_page(p['AuctionTable'])
        parse_history_page(p['AuctionHistory'], bids_list)
        auction_collection.insert_one(auction_dict,{"ordered":"True"})
        bids_collection.insert_many(bids_list)
#        myquery = { "_id": qauction_id }
#        newvalues = { "$set": auction_dict }
#        print(auction_dict)
#        break;
#        pages_collection.update_one(myquery, newvalues)
#        myquery = { "_id": qauction_id }
#        unsetlist = {k:1 for k in auction_dict.keys() if k not in ["qauctionid"]} 
#        unsetvalues = {"$unset":unsetlist}
#        print(unsetvalues)
#        pages_collection.update_one(myquery, unsetvalues)
        #auction_list.append(auction_dict)



#    for d in auction_list:
#        if d["tracking"] == 100.00:
#            sql = "INSERT INTO Auctions (qauctionid, cardvalue, bidvalue, tracking, auctiontime, runtime, limited_allowed, cashvalue) VALUES (%s, %s, %s, %s, %s, %s, %s, %s)"
#            cursor.execute(sql, (d['qauctionid'], d['cardvalue'], d['bidvalue'], d['tracking'], d['auctiontime'], d['runtime'], d['limited_allowed'], d['cashvalue']))
#        print (d.auction_dict.count())
#        for k, v  in d.auction_dict.items():
#            print(k, v)
            
            
#    conn.commit()
 
    
    # connection is not autocommit by default. So you must commit to save
    # your changes.
# Out:
# 265936045 amazon50bids20
# 'parse_auction_page'  0.06 ms
# 'parse_auction_table_page'  7.35 ms
# 'parse_history_page'  76.82 ms
# 585652307 amazon50bids20
# 'parse_auction_page'  0.05 ms
# 'parse_auction_table_page'  13.30 ms
# 'parse_history_page'  264.23 ms
# 778393197 amazon50bids20
# 'parse_auction_page'  0.05 ms
# 'parse_auction_table_page'  6.63 ms
# 'parse_history_page'  92.78 ms
# 643682635 amazon50bids20
# 'parse_auction_page'  0.05 ms
# 'parse_auction_table_page'  6.46 ms
# 'parse_history_page'  123.71 ms
# 782287760 amazon50bids20
# 'parse_auction_page'  0.07 ms
# 'parse_auction_table_page'  4.39 ms
# 'parse_history_page'  6.51 ms
# 261136026 amazon50bids30
# 'parse_auction_page'  0.05 ms
# 'parse_auction_table_page'  5.94 ms
# 'parse_history_page'  30.86 ms
# 218837987 amazon50bids30
# 'parse_auction_page'  0.05 ms
# 'parse_auction_table_page'  12.84 ms
# 'parse_history_page'  703.23 ms
# 691662580 amazon50bids30
# 'parse_auction_page'  0.05 ms
# 'parse_auction_table_page'  10.83 ms
# 'parse_history_page'  203.74 ms
# 200966294 amazon50bids30
# 'parse_auction_page'  0.06 ms
# 'parse_auction_table_page'  7.69 ms
# 'parse_history_page'  72.52 ms
# 838449008 amazon50bids30
# 'parse_auction_page'  0.05 ms
# 'parse_auction_table_page'  7.56 ms
# 'parse_history_page'  70.51 ms
# 966689709 amazon25bids20
# 'parse_auction_page'  0.05 ms
# 'parse_auction_table_page'  3.66 ms
# 'parse_history_page'  5.01 ms
# 579416214 amazon25bids20
# 'parse_auction_page'  0.05 ms
# 'parse_auction_table_page'  4.84 ms
# 'parse_history_page'  9.16 ms
# 894524425 amazon25bids20
# 'parse_auction_page'  0.05 ms
# 'parse_auction_table_page'  6.46 ms
# 'parse_history_page'  27.88 ms
# 743352602 amazon25bids20
# 'parse_auction_page'  0.06 ms
# 'parse_auction_table_page'  3.77 ms
# 'parse_history_page'  6.06 ms
# 163894233 amazon25bids20
# 'parse_auction_page'  0.05 ms
# 'parse_auction_table_page'  6.41 ms
# 'parse_history_page'  54.70 ms
# 365299753 amazon25bids30
# 'parse_auction_page'  0.04 ms
# 'parse_auction_table_page'  5.88 ms
# 'parse_history_page'  56.77 ms
# 240214848 amazon25bids30
# 'parse_auction_page'  0.06 ms
# 'parse_auction_table_page'  8.95 ms
# 'parse_history_page'  56.63 ms
# 831697389 amazon25bids30
# 'parse_auction_page'  0.05 ms
# 'parse_auction_table_page'  6.61 ms
# 'parse_history_page'  38.98 ms
# 262759996 amazon25bids30
# 'parse_auction_page'  0.05 ms
# 'parse_auction_table_page'  3.66 ms
# 'parse_history_page'  9.84 ms
# 378080073 amazon25bids30
# 'parse_auction_page'  0.05 ms
# 'parse_auction_table_page'  6.90 ms
# 'parse_history_page'  61.57 ms
# 589178016 shell50bids30
# 'parse_auction_page'  0.05 ms
# 'parse_auction_table_page'  6.59 ms
# 'parse_history_page'  11.06 ms
# 627798495 shell50bids30
# 'parse_auction_page'  0.05 ms
# 'parse_auction_table_page'  9.18 ms
# 'parse_history_page'  231.19 ms
# 481543295 shell50bids30
# 'parse_auction_page'  0.05 ms
# 'parse_auction_table_page'  4.70 ms
# 'parse_history_page'  552.34 ms
# 883964867 shell50bids30
# 'parse_auction_page'  0.06 ms
# 'parse_auction_table_page'  4.05 ms
# 'parse_history_page'  5.73 ms
# 330470322 shell50bids30
# 'parse_auction_page'  0.06 ms
# 'parse_auction_table_page'  6.52 ms
# 'parse_history_page'  23.62 ms
# 840116727 shell50bids20
# 'parse_auction_page'  0.05 ms
# 'parse_auction_table_page'  10.61 ms
# 'parse_history_page'  93.80 ms
# 240675470 shell50bids20
# 'parse_auction_page'  0.05 ms
# 'parse_auction_table_page'  5.86 ms
# 'parse_history_page'  18.24 ms
# 341912836 shell50bids20
# 'parse_auction_page'  0.05 ms
# 'parse_auction_table_page'  6.72 ms
# 'parse_history_page'  100.63 ms
# 586368435 shell50bids20
# 'parse_auction_page'  0.06 ms
# 'parse_auction_table_page'  9.96 ms
# 'parse_history_page'  139.40 ms
# 630305414 shell50bids20
# 'parse_auction_page'  0.06 ms
# 'parse_auction_table_page'  9.58 ms
# 'parse_history_page'  175.56 ms
# 802323736 shell25bids20
# 'parse_auction_page'  0.07 ms
# 'parse_auction_table_page'  10.16 ms
# 'parse_history_page'  65.98 ms
# 285820628 shell25bids20
# 'parse_auction_page'  0.05 ms
# 'parse_auction_table_page'  6.50 ms
# 'parse_history_page'  83.78 ms
# 661310368 shell25bids20
# 'parse_auction_page'  0.05 ms
# 'parse_auction_table_page'  2.59 ms
# 'parse_history_page'  4.04 ms
# 637319166 shell25bids20
# 'parse_auction_page'  0.05 ms
# 'parse_auction_table_page'  4.20 ms
# 'parse_history_page'  5.87 ms
# 816982537 shell25bids20
# 'parse_auction_page'  0.04 ms
# 'parse_auction_table_page'  6.88 ms
# 'parse_history_page'  49.72 ms
# 998463069 target25bids20
# 'parse_auction_page'  0.05 ms
# 'parse_auction_table_page'  8.46 ms
# 'parse_history_page'  51.28 ms
# 777328801 target25bids20
# 'parse_auction_page'  0.05 ms
# 'parse_auction_table_page'  2.92 ms
# 'parse_history_page'  6.69 ms
# 777755064 target25bids20
# 'parse_auction_page'  0.05 ms
# 'parse_auction_table_page'  4.52 ms
# 'parse_history_page'  8.26 ms
# 694710207 target25bids20
# 'parse_auction_page'  0.05 ms
# 'parse_auction_table_page'  4.86 ms
# 'parse_history_page'  35.70 ms
# 672380688 target25bids20
# 'parse_auction_page'  0.05 ms
# 'parse_auction_table_page'  6.70 ms
# 'parse_history_page'  16.66 ms
# 784064357 walmart25bids20
# 'parse_auction_page'  0.06 ms
# 'parse_auction_table_page'  3.96 ms
# 'parse_history_page'  22.74 ms
# 676086661 walmart25bids20
# 'parse_auction_page'  0.05 ms
# 'parse_auction_table_page'  4.43 ms
# 'parse_history_page'  9.81 ms
# 758050983 walmart25bids20
# 'parse_auction_page'  0.05 ms
# 'parse_auction_table_page'  4.36 ms
# 'parse_history_page'  9.64 ms
# 934703815 walmart25bids20
# 'parse_auction_page'  0.05 ms
# 'parse_auction_table_page'  7.11 ms
# 'parse_history_page'  43.56 ms
# 648412789 walmart25bids20
# 'parse_auction_page'  0.05 ms
# 'parse_auction_table_page'  5.90 ms
# 'parse_history_page'  12.76 ms
# 778134931 walmart25bids30
# 'parse_auction_page'  0.05 ms
# 'parse_auction_table_page'  6.90 ms
# 'parse_history_page'  40.43 ms
# 692391864 walmart25bids30
# 'parse_auction_page'  0.05 ms
# 'parse_auction_table_page'  9.13 ms
# 'parse_history_page'  673.19 ms
# 844157471 walmart25bids30
# 'parse_auction_page'  0.08 ms
# 'parse_auction_table_page'  3.93 ms
# 'parse_history_page'  18.16 ms
# 739019591 walmart25bids30
# 'parse_auction_page'  0.05 ms
# 'parse_auction_table_page'  4.28 ms
# 'parse_history_page'  10.84 ms
# 940647982 walmart25bids30
# 'parse_auction_page'  0.05 ms
# 'parse_auction_table_page'  10.16 ms
# 'parse_history_page'  66.07 ms
# 852174047 homedepot25bids30
# 'parse_auction_page'  0.05 ms
# 'parse_auction_table_page'  4.51 ms
# 'parse_history_page'  6.89 ms
# 181302124 homedepot25bids30
# 'parse_auction_page'  0.05 ms
# 'parse_auction_table_page'  2.79 ms
# 'parse_history_page'  11.24 ms
# 413140449 homedepot25bids30
# 'parse_auction_page'  0.05 ms
# 'parse_auction_table_page'  3.73 ms
# 'parse_history_page'  14.87 ms
# 482160638 homedepot25bids30
# 'parse_auction_page'  0.07 ms
# 'parse_auction_table_page'  7.60 ms
# 'parse_history_page'  5.64 ms
# 547900200 homedepot25bids30
# 'parse_auction_page'  0.05 ms
# 'parse_auction_table_page'  6.64 ms
# 'parse_history_page'  109.78 ms
# 666966803 homedepot25bids20
# 'parse_auction_page'  0.05 ms
# 'parse_auction_table_page'  12.41 ms
# 'parse_history_page'  100.85 ms
# 561221363 homedepot25bids20
# 'parse_auction_page'  0.09 ms
# 'parse_auction_table_page'  7.47 ms
# 'parse_history_page'  10.34 ms
# 520762561 homedepot25bids20
# 'parse_auction_page'  0.05 ms
# 'parse_auction_table_page'  8.21 ms
# 'parse_history_page'  16.82 ms
# 714792928 homedepot25bids20
# 'parse_auction_page'  0.06 ms
# 'parse_auction_table_page'  7.10 ms
# 'parse_history_page'  17.09 ms
# 392553425 homedepot25bids20
# 'parse_auction_page'  0.06 ms
# 'parse_auction_table_page'  11.15 ms
# 'parse_history_page'  118.87 ms
# 453825602 homedepot50bids0
# 'parse_auction_page'  0.07 ms
# 'parse_auction_table_page'  6.00 ms
# 'parse_history_page'  19.49 ms
# 778309683 homedepot50bids0
# 'parse_auction_page'  0.05 ms
# 'parse_auction_table_page'  4.94 ms
# 'parse_history_page'  41.24 ms
# 368763473 homedepot50bids0
# 'parse_auction_page'  0.06 ms
# 'parse_auction_table_page'  4.45 ms
# 'parse_history_page'  17.09 ms
# 521685667 homedepot50bids0
# 'parse_auction_page'  0.08 ms
# 'parse_auction_table_page'  5.45 ms
# 'parse_history_page'  61.16 ms
# 787059107 homedepot50bids0
# 'parse_auction_page'  0.05 ms
# 'parse_auction_table_page'  4.37 ms
# 'parse_history_page'  16.76 ms
# 796154249 amazon150bids30
# 'parse_auction_page'  0.08 ms
# 'parse_auction_table_page'  35.79 ms
# 'parse_history_page'  351.44 ms
# 549817506 amazon150bids30
# 'parse_auction_page'  0.05 ms
# 'parse_auction_table_page'  11.69 ms
# 'parse_history_page'  653.30 ms
# 250204855 amazon150bids30
# 'parse_auction_page'  0.06 ms
# 'parse_auction_table_page'  13.31 ms
# 'parse_history_page'  136.80 ms
# 317220059 amazon150bids30
# 'parse_auction_page'  0.06 ms
# 'parse_auction_table_page'  7.30 ms
# 'parse_history_page'  61.78 ms
# 444641853 amazon150bids30
# 'parse_auction_page'  0.06 ms
# 'parse_auction_table_page'  7.93 ms
# 'parse_history_page'  20.88 ms
# 651463316 amazon100bids30
# 'parse_auction_page'  0.07 ms
# 'parse_auction_table_page'  26.99 ms
# 'parse_history_page'  255.25 ms
# 774195265 amazon100bids30
# 'parse_auction_page'  0.05 ms
# 'parse_auction_table_page'  10.83 ms
# 'parse_history_page'  141.47 ms
# 502921069 amazon100bids30
# 'parse_auction_page'  0.05 ms
# 'parse_auction_table_page'  20.86 ms
# 'parse_history_page'  430.09 ms
# 917461267 amazon100bids30
# 'parse_auction_page'  0.05 ms
# 'parse_auction_table_page'  16.26 ms
# 'parse_history_page'  701.02 ms
# 917854562 amazon100bids30
# 'parse_auction_page'  0.05 ms
# 'parse_auction_table_page'  6.94 ms
# 'parse_history_page'  18.20 ms
# 633387725 amazon75bids30
# 'parse_auction_page'  0.05 ms
# 'parse_auction_table_page'  14.91 ms
# 'parse_history_page'  296.14 ms
# 233546875 amazon75bids30
# 'parse_auction_page'  0.05 ms
# 'parse_auction_table_page'  16.88 ms
# 'parse_history_page'  164.49 ms
# 375057340 amazon75bids30
# 'parse_auction_page'  0.05 ms
# 'parse_auction_table_page'  11.67 ms
# 'parse_history_page'  199.97 ms
# 860039395 amazon75bids30
# 'parse_auction_page'  0.05 ms
# 'parse_auction_table_page'  19.06 ms
# 'parse_history_page'  747.85 ms
# 323066439 amazon75bids30
# 'parse_auction_page'  0.06 ms
# 'parse_auction_table_page'  25.54 ms
# 'parse_history_page'  215.35 ms
# 903862144 amazon50bids20
# 'parse_auction_page'  0.05 ms
# 'parse_auction_table_page'  5.04 ms
# 'parse_history_page'  24.79 ms
# 790638256 amazon50bids20
# 'parse_auction_page'  0.07 ms
# 'parse_auction_table_page'  7.01 ms
# 'parse_history_page'  49.76 ms
# 377657408 amazon50bids20
# 'parse_auction_page'  0.07 ms
# 'parse_auction_table_page'  6.02 ms
# 'parse_history_page'  23.89 ms
# 868276881 amazon50bids20
# 'parse_auction_page'  0.06 ms
# 'parse_auction_table_page'  6.04 ms
# 'parse_history_page'  7.44 ms
# 782618520 amazon50bids20
# 'parse_auction_page'  0.09 ms
# 'parse_auction_table_page'  17.91 ms
# 'parse_history_page'  127.71 ms
# 537995739 amazon50bids30
# 'parse_auction_page'  0.06 ms
# 'parse_auction_table_page'  6.95 ms
# 'parse_history_page'  9.51 ms
# 302724135 amazon50bids30
# 'parse_auction_page'  0.05 ms
# 'parse_auction_table_page'  7.11 ms
# 'parse_history_page'  41.99 ms
# 352959945 amazon50bids30
# 'parse_auction_page'  0.05 ms
# 'parse_auction_table_page'  13.42 ms
# 'parse_history_page'  208.44 ms
# 953876074 amazon50bids30
# 'parse_auction_page'  0.08 ms
# 'parse_auction_table_page'  4.63 ms
# 'parse_history_page'  14.89 ms
# 767260934 amazon50bids30
# 'parse_auction_page'  0.10 ms
# 'parse_auction_table_page'  28.84 ms
# 'parse_history_page'  131.64 ms
# 254978681 amazon50bids35
# 'parse_auction_page'  0.06 ms
# 'parse_auction_table_page'  12.42 ms
# 'parse_history_page'  198.02 ms
# 977324876 amazon50bids35
# 'parse_auction_page'  0.06 ms
# 'parse_auction_table_page'  485.14 ms
# 'parse_history_page'  87.94 ms
# 639350055 amazon50bids35
# 'parse_auction_page'  0.05 ms
# 'parse_auction_table_page'  14.83 ms
# 'parse_history_page'  179.25 ms
# 515077253 amazon50bids35
# 'parse_auction_page'  0.06 ms
# 'parse_auction_table_page'  7.43 ms
# 'parse_history_page'  9.88 ms
# 329751774 amazon50bids35
# 'parse_auction_page'  0.06 ms
# 'parse_auction_table_page'  14.53 ms
# 'parse_history_page'  38.05 ms
# 390743830 amazon25bids20
# 'parse_auction_page'  0.05 ms
# 'parse_auction_table_page'  6.55 ms
# 'parse_history_page'  15.56 ms
# 805082515 amazon25bids20
# 'parse_auction_page'  0.05 ms
# 'parse_auction_table_page'  13.76 ms
# 'parse_history_page'  62.62 ms
# 732805553 amazon25bids20
# 'parse_auction_page'  0.05 ms
# 'parse_auction_table_page'  11.50 ms
# 'parse_history_page'  98.73 ms
# 680593963 amazon25bids20
# 'parse_auction_page'  0.06 ms
# 'parse_auction_table_page'  7.37 ms
# 'parse_history_page'  9.25 ms
# 753403414 amazon25bids20
# 'parse_auction_page'  0.06 ms
# 'parse_auction_table_page'  7.93 ms
# 'parse_history_page'  12.94 ms
# 943732766 amazon25bids30
# 'parse_auction_page'  0.05 ms
# 'parse_auction_table_page'  4.56 ms
# 'parse_history_page'  8.02 ms
# 257795894 amazon25bids30
# 'parse_auction_page'  0.06 ms
# 'parse_auction_table_page'  6.12 ms
# 'parse_history_page'  7.87 ms
# 879088767 amazon25bids30
# 'parse_auction_page'  0.06 ms
# 'parse_auction_table_page'  15.28 ms
# 'parse_history_page'  96.66 ms
# 771626669 amazon25bids30
# 'parse_auction_page'  0.05 ms
# 'parse_auction_table_page'  6.80 ms
# 'parse_history_page'  7.99 ms
# 303745335 amazon25bids30
# 'parse_auction_page'  0.05 ms
# 'parse_auction_table_page'  3.39 ms
# 'parse_history_page'  49.06 ms
# 680029565 shell50bids30
# 'parse_auction_page'  0.08 ms
# 'parse_auction_table_page'  16.17 ms
# 'parse_history_page'  86.11 ms
# 131969200 shell50bids30
# 'parse_auction_page'  0.04 ms
# 'parse_auction_table_page'  8.06 ms
# 'parse_history_page'  186.46 ms
# 246616134 shell50bids30
# 'parse_auction_page'  0.05 ms
# 'parse_auction_table_page'  3.94 ms
# 'parse_history_page'  19.18 ms
# 432098454 shell50bids30
# 'parse_auction_page'  0.05 ms
# 'parse_auction_table_page'  7.41 ms
# 'parse_history_page'  70.21 ms
# 883322394 shell50bids30
# 'parse_auction_page'  0.05 ms
# 'parse_auction_table_page'  5.44 ms
# 'parse_history_page'  23.75 ms
# 941513637 shell50bids20
# 'parse_auction_page'  0.05 ms
# 'parse_auction_table_page'  4.44 ms
# 'parse_history_page'  9.76 ms
# 971353049 shell50bids20
# 'parse_auction_page'  0.05 ms
# 'parse_auction_table_page'  4.65 ms
# 'parse_history_page'  28.59 ms
# 320976184 shell50bids20
# 'parse_auction_page'  0.06 ms
# 'parse_auction_table_page'  12.17 ms
# 'parse_history_page'  625.74 ms
# 571854597 shell50bids20
# 'parse_auction_page'  0.06 ms
# 'parse_auction_table_page'  9.83 ms
# 'parse_history_page'  51.56 ms
# 421568072 shell50bids20
# 'parse_auction_page'  0.06 ms
# 'parse_auction_table_page'  15.87 ms
# 'parse_history_page'  81.73 ms
# 620068206 shell50bids35
# 'parse_auction_page'  0.06 ms
# 'parse_auction_table_page'  7.50 ms
# 'parse_history_page'  10.04 ms
# 242482966 shell50bids35
# 'parse_auction_page'  0.06 ms
# 'parse_auction_table_page'  11.41 ms
# 'parse_history_page'  360.19 ms
# 917552682 shell50bids35
# 'parse_auction_page'  0.07 ms
# 'parse_auction_table_page'  10.29 ms
# 'parse_history_page'  21.30 ms
# 282908848 shell50bids35
# 'parse_auction_page'  0.05 ms
# 'parse_auction_table_page'  15.81 ms
# 'parse_history_page'  81.22 ms
# 459329909 shell50bids35
# 'parse_auction_page'  0.05 ms
# 'parse_auction_table_page'  9.75 ms
# 'parse_history_page'  168.04 ms
# 523443955 shell25bids20
# 'parse_auction_page'  0.06 ms
# 'parse_auction_table_page'  17.22 ms
# 'parse_history_page'  95.39 ms
# 543965721 shell25bids20
# 'parse_auction_page'  0.05 ms
# 'parse_auction_table_page'  9.63 ms
# 'parse_history_page'  52.09 ms
# 603811104 shell25bids20
# 'parse_auction_page'  0.08 ms
# 'parse_auction_table_page'  8.62 ms
# 'parse_history_page'  48.32 ms
# 475924395 shell25bids20
# 'parse_auction_page'  0.05 ms
# 'parse_auction_table_page'  10.56 ms
# 'parse_history_page'  646.44 ms
# 113979343 shell25bids20
# 'parse_auction_page'  0.06 ms
# 'parse_auction_table_page'  4.52 ms
# 'parse_history_page'  10.90 ms
# 426924214 target25bids20
# 'parse_auction_page'  0.05 ms
# 'parse_auction_table_page'  5.09 ms
# 'parse_history_page'  14.93 ms
# 840575077 target25bids20
# 'parse_auction_page'  0.05 ms
# 'parse_auction_table_page'  6.15 ms
# 'parse_history_page'  35.88 ms
# 994413614 target25bids20
# 'parse_auction_page'  0.05 ms
# 'parse_auction_table_page'  7.08 ms
# 'parse_history_page'  76.04 ms
# 701154726 target25bids20
# 'parse_auction_page'  0.05 ms
# 'parse_auction_table_page'  4.90 ms
# 'parse_history_page'  10.97 ms
# 868932513 target25bids20
# 'parse_auction_page'  0.07 ms
# 'parse_auction_table_page'  3.97 ms
# 'parse_history_page'  6.89 ms
# 352554879 target25bids30
# 'parse_auction_page'  0.06 ms
# 'parse_auction_table_page'  22.94 ms
# 'parse_history_page'  177.08 ms
# 325078684 target25bids30
# 'parse_auction_page'  0.05 ms
# 'parse_auction_table_page'  8.57 ms
# 'parse_history_page'  42.80 ms
# 416894266 target25bids30
# 'parse_auction_page'  0.05 ms
# 'parse_auction_table_page'  8.40 ms
# 'parse_history_page'  50.25 ms
# 175422545 target25bids30
# 'parse_auction_page'  0.07 ms
# 'parse_auction_table_page'  5.50 ms
# 'parse_history_page'  22.04 ms
# 165745115 target25bids30
# 'parse_auction_page'  0.05 ms
# 'parse_auction_table_page'  3.71 ms
# 'parse_history_page'  10.01 ms
# 416864978 walmart50bids30
# 'parse_auction_page'  0.06 ms
# 'parse_auction_table_page'  8.32 ms
# 'parse_history_page'  79.85 ms
# 888942259 walmart50bids30
# 'parse_auction_page'  0.05 ms
# 'parse_auction_table_page'  26.35 ms
# 'parse_history_page'  265.98 ms
# 755723738 walmart50bids30
# 'parse_auction_page'  0.05 ms
# 'parse_auction_table_page'  3.78 ms
# 'parse_history_page'  7.61 ms
# 514984090 walmart50bids30
# 'parse_auction_page'  0.05 ms
# 'parse_auction_table_page'  8.12 ms
# 'parse_history_page'  74.89 ms
# 204808977 walmart50bids30
# 'parse_auction_page'  0.05 ms
# 'parse_auction_table_page'  11.67 ms
# 'parse_history_page'  99.49 ms
# 823079507 walmart50bids35
# 'parse_auction_page'  0.06 ms
# 'parse_auction_table_page'  17.27 ms
# 'parse_history_page'  781.68 ms
# 525474438 walmart50bids35
# 'parse_auction_page'  0.05 ms
# 'parse_auction_table_page'  9.07 ms
# 'parse_history_page'  51.12 ms
# 166718084 walmart50bids35
# 'parse_auction_page'  0.05 ms
# 'parse_auction_table_page'  8.09 ms
# 'parse_history_page'  51.10 ms
# 406360164 walmart50bids35
# 'parse_auction_page'  0.05 ms
# 'parse_auction_table_page'  7.15 ms
# 'parse_history_page'  27.57 ms
# 139327713 walmart50bids35
# 'parse_auction_page'  0.05 ms
# 'parse_auction_table_page'  7.92 ms
# 'parse_history_page'  108.06 ms
# 557082069 walmart50bids20
# 'parse_auction_page'  0.05 ms
# 'parse_auction_table_page'  11.59 ms
# 'parse_history_page'  104.68 ms
# 574102171 walmart50bids20
# 'parse_auction_page'  0.06 ms
# 'parse_auction_table_page'  11.86 ms
# 'parse_history_page'  179.31 ms
# 484080473 walmart50bids20
# 'parse_auction_page'  0.07 ms
# 'parse_auction_table_page'  4.98 ms
# 'parse_history_page'  7.14 ms
# 823235868 walmart50bids20
# 'parse_auction_page'  0.06 ms
# 'parse_auction_table_page'  6.44 ms
# 'parse_history_page'  15.24 ms
# 134311188 walmart50bids20
# 'parse_auction_page'  0.05 ms
# 'parse_auction_table_page'  3.60 ms
# 'parse_history_page'  5.99 ms
# 127621147 walmart25bids20
# 'parse_auction_page'  0.05 ms
# 'parse_auction_table_page'  9.35 ms
# 'parse_history_page'  51.21 ms
# 505783491 walmart25bids20
# 'parse_auction_page'  0.05 ms
# 'parse_auction_table_page'  10.06 ms
# 'parse_history_page'  80.45 ms
# 622628739 walmart25bids20
# 'parse_auction_page'  0.05 ms
# 'parse_auction_table_page'  4.53 ms
# 'parse_history_page'  29.36 ms
# 406562850 walmart25bids20
# 'parse_auction_page'  0.05 ms
# 'parse_auction_table_page'  8.85 ms
# 'parse_history_page'  147.97 ms
# 161549060 walmart25bids20
# 'parse_auction_page'  0.05 ms
# 'parse_auction_table_page'  8.99 ms
# 'parse_history_page'  549.24 ms
# 566373875 walmart25bids30
# 'parse_auction_page'  0.06 ms
# 'parse_auction_table_page'  7.56 ms
# 'parse_history_page'  13.87 ms
# 589825763 walmart25bids30
# 'parse_auction_page'  0.05 ms
# 'parse_auction_table_page'  12.16 ms
# 'parse_history_page'  75.80 ms
# 770202380 walmart25bids30
# 'parse_auction_page'  0.08 ms
# 'parse_auction_table_page'  12.41 ms
# 'parse_history_page'  61.41 ms
# 547431038 walmart25bids30
# 'parse_auction_page'  0.07 ms
# 'parse_auction_table_page'  6.34 ms
# 'parse_history_page'  11.19 ms
# 232925095 walmart25bids30
# 'parse_auction_page'  0.05 ms
# 'parse_auction_table_page'  5.01 ms
# 'parse_history_page'  7.82 ms
# 170275685 homedepot25bids30
# 'parse_auction_page'  0.05 ms
# 'parse_auction_table_page'  4.57 ms
# 'parse_history_page'  23.98 ms
# 659718163 homedepot25bids30
# 'parse_auction_page'  0.05 ms
# 'parse_auction_table_page'  3.62 ms
# 'parse_history_page'  9.47 ms
# 626689729 homedepot25bids30
# 'parse_auction_page'  0.05 ms
# 'parse_auction_table_page'  7.87 ms
# 'parse_history_page'  117.24 ms
# 934135780 homedepot25bids30
# 'parse_auction_page'  0.05 ms
# 'parse_auction_table_page'  4.41 ms
# 'parse_history_page'  14.19 ms
# 446327374 homedepot25bids30
# 'parse_auction_page'  0.06 ms
# 'parse_auction_table_page'  4.44 ms
# 'parse_history_page'  36.29 ms
# 611477818 homedepot25bids20
# 'parse_auction_page'  0.05 ms
# 'parse_auction_table_page'  5.13 ms
# 'parse_history_page'  6.02 ms
# 444377576 homedepot25bids20
# 'parse_auction_page'  0.05 ms
# 'parse_auction_table_page'  3.37 ms
# 'parse_history_page'  10.48 ms
# 392928456 homedepot25bids20
# 'parse_auction_page'  0.05 ms
# 'parse_auction_table_page'  10.75 ms
# 'parse_history_page'  23.17 ms
# 422920207 homedepot25bids20
# 'parse_auction_page'  0.06 ms
# 'parse_auction_table_page'  2.88 ms
# 'parse_history_page'  4.62 ms
# 160752268 homedepot50bids30
# 'parse_auction_page'  0.05 ms
# 'parse_auction_table_page'  4.79 ms
# 'parse_history_page'  27.60 ms
# 790711939 homedepot50bids30
# 'parse_auction_page'  0.05 ms
# 'parse_auction_table_page'  5.86 ms
# 'parse_history_page'  10.77 ms
# 215607379 homedepot50bids30
# 'parse_auction_page'  0.07 ms
# 'parse_auction_table_page'  12.20 ms
# 'parse_history_page'  154.49 ms
# 567163725 homedepot50bids30
# 'parse_auction_page'  0.05 ms
# 'parse_auction_table_page'  11.87 ms
# 'parse_history_page'  163.06 ms
# 487144432 homedepot50bids30
# 'parse_auction_page'  0.06 ms
# 'parse_auction_table_page'  4.99 ms
# 'parse_history_page'  13.52 ms
# 426125616 voucher0bids250
# 'parse_auction_page'  0.04 ms
# 'parse_auction_table_page'  7.60 ms
# 'parse_history_page'  76.46 ms
# 923217405 voucher0bids250
# 'parse_auction_page'  0.05 ms
# 'parse_auction_table_page'  14.47 ms
# 'parse_history_page'  126.66 ms
# 334383010 voucher0bids250
# 'parse_auction_page'  0.05 ms
# 'parse_auction_table_page'  10.91 ms
# 'parse_history_page'  660.84 ms
# 471436220 voucher0bids250
# 'parse_auction_page'  0.05 ms
# 'parse_auction_table_page'  4.70 ms
# 'parse_history_page'  183.86 ms
# 639840640 voucher0bids250
# 'parse_auction_page'  0.07 ms
# 'parse_auction_table_page'  8.60 ms
# 'parse_history_page'  78.82 ms
# 775758664 voucher0bids100
# 'parse_auction_page'  0.05 ms
# 'parse_auction_table_page'  4.18 ms
# 'parse_history_page'  20.45 ms
# 562694227 voucher0bids100
# 'parse_auction_page'  0.04 ms
# 'parse_auction_table_page'  4.92 ms
# 'parse_history_page'  52.82 ms
# 135940165 voucher0bids100
# 'parse_auction_page'  0.05 ms
# 'parse_auction_table_page'  4.83 ms
# 'parse_history_page'  15.50 ms
# 142591308 voucher0bids100
# 'parse_auction_page'  0.05 ms
# 'parse_auction_table_page'  9.51 ms
# 'parse_history_page'  33.25 ms
# 321389531 voucher0bids100
# 'parse_auction_page'  0.04 ms
# 'parse_auction_table_page'  5.05 ms
# 'parse_history_page'  23.84 ms
# 263084084 voucher0bids50
# 'parse_auction_page'  0.05 ms
# 'parse_auction_table_page'  8.68 ms
# 'parse_history_page'  33.33 ms
# 257602777 voucher0bids50
# 'parse_auction_page'  0.05 ms
# 'parse_auction_table_page'  6.64 ms
# 'parse_history_page'  24.20 ms
# 645954878 voucher0bids50
# 'parse_auction_page'  0.04 ms
# 'parse_auction_table_page'  4.48 ms
# 'parse_history_page'  6.65 ms
# 307631487 voucher0bids50
# 'parse_auction_page'  0.05 ms
# 'parse_auction_table_page'  10.88 ms
# 'parse_history_page'  37.27 ms
# 368063280 voucher0bids50
# 'parse_auction_page'  0.05 ms
# 'parse_auction_table_page'  9.72 ms
# 'parse_history_page'  34.48 ms
# 339224920 voucher0bids20
# 'parse_auction_page'  0.05 ms
# 'parse_auction_table_page'  6.11 ms
# 'parse_history_page'  6.97 ms
# 883490463 voucher0bids20
# 'parse_auction_page'  0.05 ms
# 'parse_auction_table_page'  3.78 ms
# 'parse_history_page'  6.97 ms
# 744090669 voucher0bids20
# 'parse_auction_page'  0.05 ms
# 'parse_auction_table_page'  6.18 ms
# 'parse_history_page'  14.03 ms
# 692201302 voucher0bids20
# 'parse_auction_page'  0.04 ms
# 'parse_auction_table_page'  7.35 ms
# 'parse_history_page'  6.03 ms
# 100884782 voucher0bids20
# 'parse_auction_page'  0.04 ms
# 'parse_auction_table_page'  6.80 ms
# 'parse_history_page'  9.23 ms
# 653501270 voucher0bids15
# 'parse_auction_page'  0.05 ms
# 'parse_auction_table_page'  5.56 ms
# 'parse_history_page'  7.25 ms
# 483288788 voucher0bids15
# 'parse_auction_page'  0.04 ms
# 'parse_auction_table_page'  5.43 ms
# 'parse_history_page'  9.85 ms
# 434670117 voucher0bids15
# 'parse_auction_page'  0.04 ms
# 'parse_auction_table_page'  10.71 ms
# 'parse_history_page'  16.15 ms
# 919917847 voucher0bids15
# 'parse_auction_page'  0.06 ms
# 'parse_auction_table_page'  7.35 ms
# 'parse_history_page'  10.91 ms
# 637976481 voucher0bids15
# 'parse_auction_page'  0.05 ms
# 'parse_auction_table_page'  7.93 ms
# 'parse_history_page'  15.31 ms
# 722675556 amazon150bids30
# 'parse_auction_page'  0.05 ms
# 'parse_auction_table_page'  26.28 ms
# 'parse_history_page'  1410.08 ms
# 809582721 amazon100bids30
# 'parse_auction_page'  0.06 ms
# 'parse_auction_table_page'  10.04 ms
# 'parse_history_page'  182.54 ms
# 268477525 amazon75bids30
# 'parse_auction_page'  0.07 ms
# 'parse_auction_table_page'  14.65 ms
# 'parse_history_page'  849.19 ms
# 589680481 amazon50bids30
# 'parse_auction_page'  0.05 ms
# 'parse_auction_table_page'  10.26 ms
# 'parse_history_page'  106.17 ms
# 143313455 amazon50bids35
# 'parse_auction_page'  0.05 ms
# 'parse_auction_table_page'  16.18 ms
# 'parse_history_page'  124.99 ms
# 549570810 amazon25bids20
# 'parse_auction_page'  0.05 ms
# 'parse_auction_table_page'  3.03 ms
# 'parse_history_page'  5.01 ms
# 654418347 amazon25bids30
# 'parse_auction_page'  0.07 ms
# 'parse_auction_table_page'  3.86 ms
# 'parse_history_page'  7.60 ms
# 722462041 shell50bids30
# 'parse_auction_page'  0.05 ms
# 'parse_auction_table_page'  6.85 ms
# 'parse_history_page'  29.09 ms
# 801043472 shell50bids35
# 'parse_auction_page'  0.05 ms
# 'parse_auction_table_page'  6.18 ms
# 'parse_history_page'  30.35 ms
# 328662729 shell25bids20
# 'parse_auction_page'  0.05 ms
# 'parse_auction_table_page'  5.79 ms
# 'parse_history_page'  15.79 ms
# 111405165 target25bids20
# 'parse_auction_page'  0.05 ms
# 'parse_auction_table_page'  3.91 ms
# 'parse_history_page'  7.31 ms
# 899558584 target25bids30
# 'parse_auction_page'  0.05 ms
# 'parse_auction_table_page'  5.88 ms
# 'parse_history_page'  8.68 ms
# 972834507 walmart50bids30
# 'parse_auction_page'  0.06 ms
# 'parse_auction_table_page'  12.16 ms
# 'parse_history_page'  150.68 ms
# 374537911 walmart50bids35
# 'parse_auction_page'  0.05 ms
# 'parse_auction_table_page'  6.02 ms
# 'parse_history_page'  31.06 ms
# 997580276 walmart25bids20
# 'parse_auction_page'  0.05 ms
# 'parse_auction_table_page'  4.92 ms
# 'parse_history_page'  11.65 ms
# 540067075 walmart25bids30
# 'parse_auction_page'  0.05 ms
# 'parse_auction_table_page'  4.20 ms
# 'parse_history_page'  27.49 ms
# 242316682 homedepot25bids30
# 'parse_auction_page'  0.05 ms
# 'parse_auction_table_page'  9.71 ms
# 'parse_history_page'  151.91 ms
# 576503049 homedepot25bids20
# 'parse_auction_page'  0.05 ms
# 'parse_auction_table_page'  4.17 ms
# 'parse_history_page'  5.90 ms
# 883443373 voucher0bids250
# 'parse_auction_page'  0.09 ms
# 'parse_auction_table_page'  9.31 ms
# 'parse_history_page'  37.22 ms
# 859851190 voucher0bids100
# 'parse_auction_page'  0.06 ms
# 'parse_auction_table_page'  10.24 ms
# 'parse_history_page'  120.00 ms
# 574755110 voucher0bids50
# 'parse_auction_page'  0.05 ms
# 'parse_auction_table_page'  6.13 ms
# 'parse_history_page'  8.14 ms
# 125017329 voucher0bids20
# 'parse_auction_page'  0.05 ms
# 'parse_auction_table_page'  5.38 ms
# 'parse_history_page'  21.93 ms
# 253942238 voucher0bids15
# 'parse_auction_page'  0.05 ms
# 'parse_auction_table_page'  4.48 ms
# 'parse_history_page'  6.15 ms

# %%
import pandas
bids_df = pd.DataFrame(list(bids_collection.find()))
auction_df = pd.DataFrame(list(auction_collection.find()))

# %%
auction_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 222 entries, 0 to 221
# Data columns (total 10 columns):
# _id                222 non-null int64
# qauctionid         222 non-null object
# cashvalue          222 non-null int64
# cardvalue          222 non-null int64
# bidvalue           222 non-null int64
# cardtype           222 non-null object
# limited_allowed    222 non-null bool
# tracking           222 non-null float64
# auctiontime        222 non-null datetime64[ns]
# runtime            222 non-null int64
# dtypes: bool(1), datetime64[ns](1), float64(1), int64(5), object(2)
# memory usage: 16.0+ KB

# %%
auction_df["runtime"][0]
# Out:
# 1619

# %%
for i in range(6):
    print(auction_df["auctiontime"][i])
    print(auction_df["runtime"][i])
   # bozo = datetime.strptime(auction_df["auctiontime"][i], '%m/%d/%Y %I:%M:%S %p')
    print(bozo)
# Out:
# 2020-01-26 16:42:11
# 1619
# 2020-01-26 13:35:06
# 2020-01-26 15:38:23
# 5713
# 2020-01-26 13:35:06
# 2020-01-26 15:29:19
# 2047
# 2020-01-26 13:35:06
# 2020-01-26 12:34:28
# 2357
# 2020-01-26 13:35:06
# 2020-01-26 11:10:00
# 288
# 2020-01-26 13:35:06
# 2020-01-26 13:35:06
# 784
# 2020-01-26 13:35:06

# %%
auction_df["auctiontime"][auction_df["auctiontime"][2:]=="AM"][0]
# Out:
# ---------------------------------------------------------------------------
# IndexingError                             Traceback (most recent call last)
# <ipython-input-43-4f6b7f2e7a2a> in <module>
# ----> 1 auction_df["auctiontime"][auction_df["auctiontime"][2:]=="AM"][0]
#
# ~/anaconda3/lib/python3.7/site-packages/pandas/core/series.py in __getitem__(self, key)
#    1106
#    1107         if com.is_bool_indexer(key):
# -> 1108             key = check_bool_indexer(self.index, key)
#    1109
#    1110         return self._get_with(key)
#
# ~/anaconda3/lib/python3.7/site-packages/pandas/core/indexing.py in check_bool_indexer(index, key)
#    2409         if mask.any():
#    2410             raise IndexingError(
# -> 2411                 "Unalignable boolean Series provided as "
#    2412                 "indexer (index of the boolean Series and of "
#    2413                 "the indexed object do not match)."
#
# IndexingError: Unalignable boolean Series provided as indexer (index of the boolean Series and of the indexed object do not match).

# %%
auction_df["auctiontime"][2:]
# Out:
# 2       1/26/2020 3:29:19 PM
# 3      1/26/2020 12:34:28 PM
# 4      1/26/2020 11:10:00 AM
# 5       1/26/2020 1:35:06 PM
# 6      1/26/2020 11:44:12 AM
#                ...
# 217      2/1/2020 4:14:37 PM
# 218      2/1/2020 5:21:50 PM
# 219      2/1/2020 5:18:09 PM
# 220      2/1/2020 5:31:08 PM
# 221      2/1/2020 5:35:12 PM
# Name: auctiontime, Length: 220, dtype: object

# %%
auction_df["runtime"]
# Out:
# 0      00:26:59
# 1      01:35:13
# 2      00:34:07
# 3      00:39:17
# 4      00:04:48
#          ...
# 217    00:16:27
# 218    00:49:45
# 219    00:05:14
# 220    00:11:22
# 221    00:04:28
# Name: runtime, Length: 222, dtype: object

# %%
myclient = pymongo.MongoClient("mongodb://localhost:27017/")
db = myclient["penny"]
auction_collection = db["auctions"]
bids_collection = db["bids"]

conn = pg2.connect(user='postgres',  dbname='penny', host='localhost', port='5432', password='')
with conn.cursor() as cursor:
 
    sql = "SELECT qauctionid from auctions"
    cursor.execute(sql)
    already_found_qids = [x[0] for x in cursor.fetchall()]


    for d in auction_collection.find({ "_id": { "$nin":  already_found_qids}}):
        if d["tracking"] == 100.00:
            lock_price = d['lock_price']
            if (not lock_price):
                lock_price = 0
            sql = "INSERT INTO Auctions (qauctionid, cardvalue, bidvalue, tracking, auctiontime, runtime, limited_allowed, cashvalue, cardtype, lock_price) VALUES (%s, %s, %s, %s, %s, %s, %s, %s, %s, %s)"
            cursor.execute(sql, (d['_id'], d['cardvalue'], d['bidvalue'], d['tracking'], d['auctiontime'], d['runtime'], d['limited_allowed'], d['cashvalue'], d['cardtype'], lock_price))
    conn.commit()

    sql = "SELECT distinct auctionid from bids"
    cursor.execute(sql)
    already_found_qids = [x[0] for x in cursor.fetchall()]
  
    for b in bids_collection.find({ "auction_id": { "$nin":  already_found_qids}}):
        sql = "INSERT INTO bids (auctionid, bid, username, is_bidomatic) VALUES (%s, %s, %s, %s)"
        cursor.execute(sql, (b['auction_id'], b['bid'], b['user'], b['is_bidomatic']))
        
    conn.commit()
    
    
conn.close()

# %%
for p in pages_collection.find({"_id": "218837987"}):
    print(p['AuctionTable'])
# Out:
#
#
#     <table style="width:100%;border-collapse:collapse;">
#         <tr>
#             <td> 100.00% Tracking </td>
#             <td style="text-align:center"> Last Engine update: 1/26/2020 11:44:12 AM</td>
#             <td style="text-align:center" id="idactive_bidders"> Active Bidders: 0</td>
#             <td style="text-align:right"> Auction runtime : 01:20:06</td>
#             <td id="refresh_time"></td>
#         </tr>
#     </table>
#
#     <div style="padding-bottom:5px;">
#
#     <a href="History?site=quibids&auction_id=218837987"> Full History </a> &nbsp; &nbsp;<a href=AuctionListByDesc?site=quibids&hash=1119122541> Similar Items </a> &nbsp; &nbsp;<a href=QChooseit?auction_id=218837987> Choose It Options</a>
#
#     </div>
#     <div id="div_progress" ></div>
#
#
#     <div id="div_auction_ended" style="display: none;">Ended</div>
#
#
#     <div id="id_cdf" class="cdfbar" style="display:none;"" " >
#
#         <div class="cdfbarleft" title="CDF shows 0.00% probability the auction will end now"   style="width:0% !important;" >
#
#             <div class="cdftext" >
#                  <a class="cdfahref" href="https://en.wikipedia.org/wiki/Cumulative_distribution_function" target="_blank">CDF 0.00%</a>
#             </div>
#
#         </div>
#
#         <div class="cdfbarright"></div>
#
#     </div>
#
#     <table class="table-bids" id="table-bids">
#
#         <tr class="tr-header">
#
#             <th class="td-header">Time</th>
#             <th class="td-header">Price</th>
#             <th class="td-header">User</th>
#
#             <th class="td-header">Single</td><th class="td-header">Bidomatic</td>
#             <th class="td-header">Bids Placed</th>
#             <th class="td-header">Bids Left(BIN)</th>
#              <th class="td-header">Bid Type</td>
#         </tr>
#
#
#          <tr class="tr-inner"><td class="td-inner">05:40:26</td><td class="td-inner">$9.93</td><td  class="td-inner"><div style="position: relative; z-index:1;bottom:-6px;float:right;text-align:right;font-size:11px"> 91%</div><div style="position:relative; height:100%;"><div style="position:relative; z-index:1;"><a href="UserAuctions?site=quibids&user=kimjking">kimjking<img style="position: relative;top: -1px"  title="User wins/bins above 81.00% of the time" src="binner.png" height="20" width="20"/><img style="position: relative;top: -1px"  title="User blocks at one second" src="robot.png" height="20" width="20"/></a></div><div style="position:absolute; left:0px; bottom:0px;background: linear-gradient(to right,cyan 77%, red 23%);width: 91%;height: 15%"></div</div></td><td class="td-inner">20</td><td class="td-inner">98</td><td class="td-inner">118</td><td class="td-inner">12</td><td class="td-inner">Bidomatic</td></tr><tr class="tr-inner"><td class="td-inner">05:40:34</td><td class="td-inner">$9.92</td><td  class="td-inner"><div style="position:relative; height:100%;"><div style="position:relative; z-index:1;"><a href="UserAuctions?site=quibids&user=cweetp1021">cweetp1021<img style="position: relative;top: -1px"  title="User wins/bins above 69.00% of the time" src="binner.png" height="20" width="20"/><img style="position: relative;top: -1px"  title="User blocks at one second" src="robot.png" height="20" width="20"/></a></div><div style="position:absolute; left:0px; bottom:0px;background-color: cyan;width: 7%;height: 15%"></div</div></td><td class="td-inner">1</td><td class="td-inner">8</td><td class="td-inner">9</td><td class="td-inner">121</td><td class="td-inner">Bidomatic</td></tr><tr class="tr-inner"><td class="td-inner">05:40:57</td><td class="td-inner">$9.87</td><td  class="td-inner"><div style="position:relative; height:100%;"><div style="position:relative; z-index:1;"><a href="UserAuctions?site=quibids&user=gumbeaux6">gumbeaux6<img style="position: relative;top: -1px"  title="User wins/bins above 62.00% of the time" src="binner.png" height="20" width="20"/><img style="position: relative;top: -1px"  title="User blocks at one second" src="robot.png" height="20" width="20"/></a></div><div style="position:absolute; left:0px; bottom:0px;background-color: cyan;width: 12%;height: 15%"></div</div></td><td class="td-inner">16</td><td class="td-inner">0</td><td class="td-inner">16</td><td class="td-inner">114</td><td class="td-inner">Single Bid</td></tr><tr class="tr-inner"><td class="td-inner">05:41:48</td><td class="td-inner">$9.8</td><td  class="td-inner"><div style="position: relative; z-index:1;bottom:-6px;float:right;text-align:right;font-size:11px"> 48%</div><div style="position:relative; height:100%;"><div style="position:relative; z-index:1;"><a href="UserAuctions?site=quibids&user=wrigl">wrigl<img style="position: relative;top: -1px"  title="User blocks at one second" src="robot.png" height="20" width="20"/></a></div><div style="position:absolute; left:0px; bottom:0px;background-color: cyan;width: 48%;height: 15%"></div</div></td><td class="td-inner">43</td><td class="td-inner">20</td><td class="td-inner">63</td><td class="td-inner">67</td><td class="td-inner">Bidomatic</td></tr><tr class="tr-inner"><td class="td-inner">05:54:13</td><td class="td-inner">$8.6</td><td  class="td-inner"><div style="position: relative; z-index:1;bottom:-6px;float:right;text-align:right;font-size:11px"> 140%</div><div style="position:relative; height:100%;"><div style="position:relative; z-index:1;"><a href="UserAuctions?site=quibids&user=samwjones">samwjones<img style="position: relative;top: -1px"  title="User wins/bins above 72.00% of the time" src="binner.png" height="20" width="20"/><img style="position: relative;top: -1px"  title="User blocks at one second" src="robot.png" height="20" width="20"/></a></div><div style="position:absolute; left:0px; bottom:0px;background: linear-gradient(to right,cyan 70%, red 30%);width: 100%;height: 15 ...
#
#     </table>
#
#     <div id="div_number_binners" style="display: none;">5</div>
#     <div id="div_all_bidders" style="display: none;">19</div>
#     <div id="div_lock_status" style="display: none;">6</div>
#     <div id="div_lock_prcnt" style="display: none;">9.68</div>
#     <div id="div_site_income" style="display: none;">74.44</div>
#     <div id="div_cdf" style="display: none;">0.00</div>

# %%
auction_collection[1]
# Out:
# Collection(Database(MongoClient(host=['localhost:27017'], document_class=dict, tz_aware=False, connect=True), 'penny'), 'auctions.1')
